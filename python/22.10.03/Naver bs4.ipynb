# %% [markdown]
# ## 1. BeautifulSoup Basic
# - https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# ```
#     - conda install -c anaconda beautifulsoup4
#     - pip install beautifulsoup4
# ```
# - data
#     - 03.test_first.html

# %%
# import 
from bs4 import BeautifulSoup

# %%
page = open('myHTML.html', 'r').read()
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    myHTML
#   </title>
#  </head>
#  <body>
#   <div id="first-id">
#    first-id의 div 태그입니다.
#   </div>
#   <div class="first-class">
#    first-class의 div 태그입니다.
#   </div>
#   <div class="second-class" id="second-id">
#    second-id와 second-class가 같이 있습니다.
#   </div>
#   <a href="https://www.naver.com">
#    Naver_Link
#   </a>
#   <br/>
#   <span style="background-color:red">
#    span 태그입니다.
#   </span>
#  </body>
# </html>

# %%
# head 태그 확인 
soup.head
# Out:
# <head>
# <title>myHTML</title>
# </head>

# %%
# body 태그 확인
soup.body
# Out:
# <body>
# <div id="first-id">first-id의 div 태그입니다.</div>
# <div class="first-class">first-class의 div 태그입니다.</div>
# <div class="second-class" id="second-id">second-id와 second-class가 같이 있습니다.</div>
# <a href="https://www.naver.com">Naver_Link</a><br/>
# <span style="background-color:red">span 태그입니다.</span>
# </body>

# %%
# div 태그 확인
# 처음 발견한 div 태그만 출력
# find() 
soup.div
# Out:
# <div id="first-id">first-id의 div 태그입니다.</div>

# %%
soup.find('div')
# Out:
# <div id="first-id">first-id의 div 태그입니다.</div>

# %%
# 파이썬 예약어는 사용하지 않는 것이 좋습니다.
# class, id, def, list, str, int, tuple...

# %%
soup.find('div', class_='second-class')
# Out:
# <div class="second-class" id="second-id">second-id와 second-class가 같이 있습니다.</div>

# %%
soup.find('div', {'id':'first-id'}).text
# Out:
# 'first-id의 div 태그입니다.'

# %%
# 다중 조건 
soup.find('div', {'class':'', "id":"first"})
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy ZeroBase.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
# find_all(): 여러 개의 태그를 리스트 형태로 반환

soup.find_all('div')
# Out:
# [<div id="first-id">first-id의 div 태그입니다.</div>,
#  <div class="first-class">first-class의 div 태그입니다.</div>,
#  <div class="second-class" id="second-id">second-id와 second-class가 같이 있습니다.</div>]

# %%
# 특정 태그 확인 
soup.find_all(id='first-id')[0].text
# Out:
# 'first-id의 div 태그입니다.'

# %%
len(soup.find_all('div'))
# Out:
# 3

# %%
# text 추출
print(soup.find_all('div')[0].text)
print(soup.find_all('div')[1].string)
print(soup.find_all('div')[1].get_text())
# Out:
# first-id의 div 태그입니다.
# first-class의 div 태그입니다.
# first-class의 div 태그입니다.

# %%
# a 태그에서 href 속성에 있는 값 추출 
links = soup.find_all('a')
# links[0].get('href'), links[1]["href"]
links[0].get('href')
# Out:
# 'https://www.naver.com'

# %%
# 자주 사용하는 전처리
soup.find('span').text.replace('.', '').split(' ')[0]
# Out:
# 'span'

# %% [markdown]
# ---

# %% [markdown]
# ## 2-1. BeautifulSoup 예제 네이버 금융

# %%
# import 
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://finance.naver.com/marketindex/'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content[:10]
# Out:
# b'\n<script l'

# %%
soup = BeautifulSoup(response.content, 'html.parser')
print(soup.prettify())
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        환전 고시 환율
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# ...

# %%
# 1 
soup.find_all("span", "value"), len(soup.find_all("span", "value"))
# Out:
# ([<span class="value">1,440.00</span>,
#   <span class="value">997.20</span>,
#   <span class="value">1,387.80</span>,
#   <span class="value">199.82</span>,
#   <span class="value">144.5500</span>,
#   <span class="value">0.9631</span>,
#   <span class="value">1.0748</span>,
#   <span class="value">114.0400</span>,
#   <span class="value">78.5</span>,
#   <span class="value">1698.14</span>,
#   <span class="value">1636.2</span>,
#   <span class="value">75283.07</span>],
#  12)

# %%
# 2 
soup.find_all("span", class_="value"), len(soup.find_all("span", "value"))
# Out:
# ([<span class="value">1,440.00</span>,
#   <span class="value">997.20</span>,
#   <span class="value">1,387.80</span>,
#   <span class="value">199.82</span>,
#   <span class="value">144.5500</span>,
#   <span class="value">0.9631</span>,
#   <span class="value">1.0748</span>,
#   <span class="value">114.0400</span>,
#   <span class="value">78.5</span>,
#   <span class="value">1698.14</span>,
#   <span class="value">1636.2</span>,
#   <span class="value">75283.07</span>],
#  12)

# %%
# 3 
soup.find_all("span", {"class":"value"}), len(soup.find_all("span", {"class":"value"}))
# Out:
# ([<span class="value">1,440.00</span>,
#   <span class="value">997.20</span>,
#   <span class="value">1,387.80</span>,
#   <span class="value">199.82</span>,
#   <span class="value">144.5500</span>,
#   <span class="value">0.9631</span>,
#   <span class="value">1.0748</span>,
#   <span class="value">114.0400</span>,
#   <span class="value">78.5</span>,
#   <span class="value">1698.14</span>,
#   <span class="value">1636.2</span>,
#   <span class="value">75283.07</span>],
#  12)

# %%
# text 추출
soup.find_all("span", {"class":"value"})[0].text, soup.find_all("span", {"class":"value"})[0].string, soup.find_all("span", {"class":"value"})[0].get_text()
# Out:
# ('1,440.00', '1,440.00', '1,440.00')

# %% [markdown]
# ## 2-2. BeautifulSoup 예제 네이버 금융
# - find, find_all
# - select, select_one
# - find, select_one : 단일 선택
# - select, find_all : 다중 선택

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://finance.naver.com/marketindex/'
response = requests.get(url)
# requests.get(), requests.post()
soup = BeautifulSoup(response.text, 'html.parser') 
print(soup.prettify())
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20220923165155/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        환전 고시 환율
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# ...

# %%
# soup.find_all("li", "on")
# id => # 
# class => . 

# 전체 리스트 가져오기 
exchangeList = soup.select("#exchangeList > li")
len(exchangeList), # exchangeList
# Out:
# (4,)

# %%
# 가져온 전체 리스트에서 세부 데이터 추출
title = exchangeList[0].select_one(".h_lst").text
exchange = exchangeList[0].select_one(".value").text
change = exchangeList[0].select_one(".change").text
updown = exchangeList[0].select_one("#exchangeList > li.on > a.head.usd > div > span.blind").text

title, exchange, change, updown
# Out:
# ('미국 USD', '1,440.00', '13.00', '상승')

# %%
# findmethod = soup.find_all("ul", id="exchangeList")
# findmethod[0].find_all("span", "value")
# Out:
# [<span class="value">1,171.20</span>,
#  <span class="value">1,063.81</span>,
#  <span class="value">1,382.95</span>,
#  <span class="value">181.70</span>]

# %%
baseUrl = "https://finance.naver.com"
baseUrl + exchangeList[0].select_one("a").get("href")
# Out:
# 'https://finance.naver.com/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW'

# %%
# 4개 데이터 수집 

exchange_datas = [] 
baseUrl = "https://finance.naver.com"

for item in exchangeList:
    data = {
        "title": item.select_one(".h_lst").text,
        "exchnage": item.select_one(".value").text,
        "change": item.select_one(".change").text,
        "updown": item.select_one("div > span.blind").text,
        "link": baseUrl + item.select_one("a").get("href")
    }
    exchange_datas.append(data)
df = pd.DataFrame(exchange_datas)
df.to_excel("./naverfinance.xlsx", encoding="utf-8")

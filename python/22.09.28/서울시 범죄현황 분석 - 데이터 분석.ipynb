# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

#f_path = "/Libary/Fonts/App/eGothic.ttf"
f_path = "C://Windows//Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
import numpy as np
import pandas as pd

# %%
crime_raw_data = pd.read_csv("./02. crime_in_Seoul.csv", encoding="UTF-8")
crime_raw_data.head()
# Out:
#      구     강간    강도   살인      절도      폭력      강간검거율       강도검거율       살인검거율  \
# 0  강남구  516.0  39.0  5.0  3587.0  4002.0  80.038760  100.000000  100.000000
# 1  강동구  160.0  14.0  4.0  1754.0  2530.0  95.000000   92.857143  100.000000
# 2  강북구  217.0   5.0  7.0  1222.0  2778.0  73.271889   80.000000   85.714286
# 3  강서구  275.0  10.0  9.0  1952.0  3204.0  86.909091  100.000000  100.000000
# 4  관악구  322.0  12.0  6.0  2103.0  3235.0  81.987578   83.333333  100.000000
#
#        절도검거율      폭력검거율
# 0  53.470867  88.130935
# 1  51.425314  86.996047
# 2  54.991817  89.344852
# 3  54.815574  86.392010
# 4  44.555397  83.678516

# %%
crime_raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65534 entries, 0 to 65533
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      310 non-null    object
#  1   죄종      310 non-null    object
#  2   발생검거    310 non-null    object
#  3   건수      310 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 2.0+ MB

# %%
crime_raw_data['죄종'].unique()
# Out:
# array(['살인', '강도', '강간', '절도', '폭력', nan], dtype=object)

# %%
crime_raw_data = crime_raw_data[crime_raw_data['죄종'].notnull()]
crime_raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 310 entries, 0 to 309
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      310 non-null    object
#  1   죄종      310 non-null    object
#  2   발생검거    310 non-null    object
#  3   건수      310 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 12.1+ KB

# %%
crime_raw_data
# Out:
#      구분  죄종 발생검거      건수
# 0    중부  살인   발생     2.0
# 1    중부  살인   검거     2.0
# 2    중부  강도   발생     3.0
# 3    중부  강도   검거     3.0
# 4    중부  강간   발생   141.0
# ..   ..  ..  ...     ...
# 305  수서  강간   검거   144.0
# 306  수서  절도   발생  1149.0
# 307  수서  절도   검거   789.0
# 308  수서  폭력   발생  1666.0
# 309  수서  폭력   검거  1431.0
#
# [310 rows x 4 columns]

# %%
df = pd.read_excel("C:/Users/ASUS/Downloads/02. sales-funnel.xlsx")
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
pd.pivot_table(df,index=['Name'])
# Out:
#                               Account   Price  Quantity
# Name
# Barton LLC                     740150   35000  1.000000
# Fritsch, Russel and Anderson   737550   35000  1.000000
# Herman LLC                     141962   65000  2.000000
# Jerde-Hilpert                  412290    5000  2.000000
# Kassulke, Ondricka and Metz    307599    7000  3.000000
# Keeling LLC                    688981  100000  5.000000
# Kiehn-Spinka                   146832   65000  2.000000
# Koepp Ltd                      729833   35000  2.000000
# Kulas Inc                      218895   25000  1.500000
# Purdy-Kunde                    163416   30000  1.000000
# Stokes LLC                     239344    7500  1.000000
# Trantow-Barrows                714466   15000  1.333333

# %%
pd.pivot_table(df,index=["Name", "Rep", "Manager"])
# Out:
#                                                           Account   Price  \
# Name                         Rep           Manager
# Barton LLC                   John Smith    Debra Henley    740150   35000
# Fritsch, Russel and Anderson Craig Booker  Debra Henley    737550   35000
# Herman LLC                   Cedric Moss   Fred Anderson   141962   65000
# Jerde-Hilpert                John Smith    Debra Henley    412290    5000
# Kassulke, Ondricka and Metz  Wendy Yule    Fred Anderson   307599    7000
# Keeling LLC                  Wendy Yule    Fred Anderson   688981  100000
# Kiehn-Spinka                 Daniel Hilton Debra Henley    146832   65000
# Koepp Ltd                    Wendy Yule    Fred Anderson   729833   35000
# Kulas Inc                    Daniel Hilton Debra Henley    218895   25000
# Purdy-Kunde                  Cedric Moss   Fred Anderson   163416   30000
# Stokes LLC                   Cedric Moss   Fred Anderson   239344    7500
# ...

# %%
pd.pivot_table(df,index=["Manager", "Rep"])
# Out:
#                               Account         Price  Quantity
# Manager       Rep
# Debra Henley  Craig Booker   720237.0  20000.000000  1.250000
#               Daniel Hilton  194874.0  38333.333333  1.666667
#               John Smith     576220.0  20000.000000  1.500000
# Fred Anderson Cedric Moss    196016.5  27500.000000  1.250000
#               Wendy Yule     614061.5  44250.000000  3.000000

# %%
pd.pivot_table(df,index=["Manager", "Rep"],values=["Price"])
# Out:
#                                     Price
# Manager       Rep
# Debra Henley  Craig Booker   20000.000000
#               Daniel Hilton  38333.333333
#               John Smith     20000.000000
# Fred Anderson Cedric Moss    27500.000000
#               Wendy Yule     44250.000000

# %%
pd.pivot_table(df,index=["Manager", "Rep"],values=["Price"],aggfunc=np.sum)
# Out:
#                               Price
# Manager       Rep
# Debra Henley  Craig Booker    80000
#               Daniel Hilton  115000
#               John Smith      40000
# Fred Anderson Cedric Moss    110000
#               Wendy Yule     177000

# %%
pd.pivot_table(df,index=["Manager", "Rep"],values=["Price"],aggfunc=[np.mean,len])
# Out:
#                                      mean   len
#                                     Price Price
# Manager       Rep
# Debra Henley  Craig Booker   20000.000000     4
#               Daniel Hilton  38333.333333     3
#               John Smith     20000.000000     2
# Fred Anderson Cedric Moss    27500.000000     4
#               Wendy Yule     44250.000000     4

# %%
pd.pivot_table(df,index=["Manager", "Rep"],values=["Price"],columns=["Product"],aggfunc=[np.mean,len])
# Out:
#                                 mean                                len  \
#                                Price                              Price
# Product                          CPU Maintenance Monitor Software   CPU
# Manager       Rep
# Debra Henley  Craig Booker   32500.0      5000.0     NaN  10000.0   2.0
#               Daniel Hilton  52500.0         NaN     NaN  10000.0   2.0
#               John Smith     35000.0      5000.0     NaN      NaN   1.0
# Fred Anderson Cedric Moss    47500.0      5000.0     NaN  10000.0   2.0
#               Wendy Yule     82500.0      7000.0  5000.0      NaN   2.0
#
#
#
# Product                     Maintenance Monitor Software
# Manager       Rep
# Debra Henley  Craig Booker          1.0     NaN      1.0
#               Daniel Hilton         NaN     NaN      1.0
#               John Smith            1.0     NaN      NaN
# Fred Anderson Cedric Moss           1.0     NaN      1.0
#               Wendy Yule            1.0     1.0      NaN

# %%
pd.pivot_table(df,index=["Manager", "Rep"],values=["Price"],columns=["Product"],aggfunc=[np.mean,len],fill_value=0)
# Out:
#                               mean                                len  \
#                              Price                              Price
# Product                        CPU Maintenance Monitor Software   CPU
# Manager       Rep
# Debra Henley  Craig Booker   32500        5000       0    10000     2
#               Daniel Hilton  52500           0       0    10000     2
#               John Smith     35000        5000       0        0     1
# Fred Anderson Cedric Moss    47500        5000       0    10000     2
#               Wendy Yule     82500        7000    5000        0     2
#
#
#
# Product                     Maintenance Monitor Software
# Manager       Rep
# Debra Henley  Craig Booker            1       0        1
#               Daniel Hilton           0       0        1
#               John Smith              1       0        0
# Fred Anderson Cedric Moss             1       0        1
#               Wendy Yule              1       1        0

# %%
pd.pivot_table(df,index=["Manager", "Rep","Product"],values=["Price","Quantity"],aggfunc=[np.sum],fill_value=0)
# Out:
#                                             sum
#                                           Price Quantity
# Manager       Rep           Product
# Debra Henley  Craig Booker  CPU           65000        2
#                             Maintenance    5000        2
#                             Software      10000        1
#               Daniel Hilton CPU          105000        4
#                             Software      10000        1
#               John Smith    CPU           35000        1
#                             Maintenance    5000        2
# Fred Anderson Cedric Moss   CPU           95000        3
#                             Maintenance    5000        1
#                             Software      10000        1
#               Wendy Yule    CPU          165000        7
#                             Maintenance    7000        3
#                             Monitor        5000        2

# %%
pd.pivot_table(df,index=["Manager", "Rep","Product"],values=["Price","Quantity"],aggfunc=[np.sum,np.mean],fill_value=0,margins=Tre)
# Out:
#                                             sum                   mean  \
#                                           Price Quantity         Price
# Manager       Rep           Product
# Debra Henley  Craig Booker  CPU           65000        2  32500.000000
#                             Maintenance    5000        2   5000.000000
#                             Software      10000        1  10000.000000
#               Daniel Hilton CPU          105000        4  52500.000000
#                             Software      10000        1  10000.000000
#               John Smith    CPU           35000        1  35000.000000
#                             Maintenance    5000        2   5000.000000
# Fred Anderson Cedric Moss   CPU           95000        3  47500.000000
#                             Maintenance    5000        1   5000.000000
#                             Software      10000        1  10000.000000
#               Wendy Yule    CPU          165000        7  82500.000000
# ...

# %%
import pandas as pd

crime_station = crime_raw_data.pivot_table(crime_raw_data, index=['구분'], columns=['죄종', '발생검거'], aggfunc=np.sum)

crime_station.head()
# Out:
#          건수
# 죄종       강간           강도          살인           절도              폭력
# 발생검거     검거     발생    검거    발생    검거   발생      검거      발생      검거      발생
# 구분
# 강남    269.0  339.0  26.0  24.0   3.0  3.0  1129.0  2438.0  2096.0  2336.0
# 강동    152.0  160.0  13.0  14.0   5.0  4.0   902.0  1754.0  2201.0  2530.0
# 강북    159.0  217.0   4.0   5.0   6.0  7.0   672.0  1222.0  2482.0  2778.0
# 강서    239.0  275.0  10.0  10.0  10.0  9.0  1070.0  1952.0  2768.0  3204.0
# 관악    264.0  322.0  10.0  12.0   7.0  6.0   937.0  2103.0  2707.0  3235.0

# %%
crime_station.columns
# Out:
# MultiIndex([('건수', '강간', '검거'),
#             ('건수', '강간', '발생'),
#             ('건수', '강도', '검거'),
#             ('건수', '강도', '발생'),
#             ('건수', '살인', '검거'),
#             ('건수', '살인', '발생'),
#             ('건수', '절도', '검거'),
#             ('건수', '절도', '발생'),
#             ('건수', '폭력', '검거'),
#             ('건수', '폭력', '발생')],
#            names=[None, '죄종', '발생검거'])

# %%
crime_station.columns = crime_station.columns.droplevel([0])
crime_station.columns
# Out:
# MultiIndex([('강간', '검거'),
#             ('강간', '발생'),
#             ('강도', '검거'),
#             ('강도', '발생'),
#             ('살인', '검거'),
#             ('살인', '발생'),
#             ('절도', '검거'),
#             ('절도', '발생'),
#             ('폭력', '검거'),
#             ('폭력', '발생')],
#            names=['죄종', '발생검거'])

# %%
crime_station['강도', '검거']
# Out:
# 구분
# 강남     26.0
# 강동     13.0
# 강북      4.0
# 강서     10.0
# 관악     10.0
# 광진      6.0
# 구로     13.0
# 금천      7.0
# 남대문     4.0
# 노원      9.0
# 도봉      5.0
# 동대문    12.0
# 동작      7.0
# 마포      7.0
# 방배      5.0
# 서대문     4.0
# 서부      2.0
# 서초      5.0
# 성동      5.0
# 성북      3.0
# 송파     12.0
# 수서     16.0
# 양천      7.0
# 영등포    14.0
# 용산     10.0
# 은평      5.0
# 종로      3.0
# 종암      5.0
# 중랑     14.0
# 중부      3.0
# 혜화      6.0
# Name: (강도, 검거), dtype: float64

# %%
crime_station['살인', '발생']
# Out:
# 구분
# 강남      3.0
# 강동      4.0
# 강북      7.0
# 강서      9.0
# 관악      6.0
# 광진      4.0
# 구로      9.0
# 금천      6.0
# 남대문     1.0
# 노원      5.0
# 도봉      3.0
# 동대문     5.0
# 동작      8.0
# 마포      4.0
# 방배      1.0
# 서대문     6.0
# 서부      4.0
# 서초      4.0
# 성동      4.0
# 성북      2.0
# 송파      9.0
# 수서      2.0
# 양천      5.0
# 영등포    13.0
# 용산      4.0
# 은평      2.0
# 종로      4.0
# 종암      2.0
# 중랑      8.0
# 중부      2.0
# 혜화      2.0
# Name: (살인, 발생), dtype: float64

# %%
crime_station.head()
# Out:
# 죄종       강간           강도          살인           절도              폭력
# 발생검거     검거     발생    검거    발생    검거   발생      검거      발생      검거      발생
# 구분
# 강남    269.0  339.0  26.0  24.0   3.0  3.0  1129.0  2438.0  2096.0  2336.0
# 강동    152.0  160.0  13.0  14.0   5.0  4.0   902.0  1754.0  2201.0  2530.0
# 강북    159.0  217.0   4.0   5.0   6.0  7.0   672.0  1222.0  2482.0  2778.0
# 강서    239.0  275.0  10.0  10.0  10.0  9.0  1070.0  1952.0  2768.0  3204.0
# 관악    264.0  322.0  10.0  12.0   7.0  6.0   937.0  2103.0  2707.0  3235.0

# %%
crime_station.loc['강남',('강도', '발생')]
# Out:
# 24.0

# %%
tmp = crime_station.columns.get_level_values(0) + crime_station.columns.get_level_values(1)
tmp
# Out:
# Index(['강간검거', '강간발생', '강도검거', '강도발생', '살인검거', '살인발생', '절도검거', '절도발생', '폭력검거',
#        '폭력발생'],
#       dtype='object')

# %%
crime_station.columns = tmp
crime_station.head()
# Out:
#      강간검거   강간발생  강도검거  강도발생  살인검거  살인발생    절도검거    절도발생    폭력검거    폭력발생
# 구분
# 강남  269.0  339.0  26.0  24.0   3.0   3.0  1129.0  2438.0  2096.0  2336.0
# 강동  152.0  160.0  13.0  14.0   5.0   4.0   902.0  1754.0  2201.0  2530.0
# 강북  159.0  217.0   4.0   5.0   6.0   7.0   672.0  1222.0  2482.0  2778.0
# 강서  239.0  275.0  10.0  10.0  10.0   9.0  1070.0  1952.0  2768.0  3204.0
# 관악  264.0  322.0  10.0  12.0   7.0   6.0   937.0  2103.0  2707.0  3235.0

# %%
crime_station
# Out:
#       강간검거   강간발생  강도검거  강도발생  살인검거  살인발생    절도검거    절도발생    폭력검거    폭력발생
# 구분
# 강남   269.0  339.0  26.0  24.0   3.0   3.0  1129.0  2438.0  2096.0  2336.0
# 강동   152.0  160.0  13.0  14.0   5.0   4.0   902.0  1754.0  2201.0  2530.0
# 강북   159.0  217.0   4.0   5.0   6.0   7.0   672.0  1222.0  2482.0  2778.0
# 강서   239.0  275.0  10.0  10.0  10.0   9.0  1070.0  1952.0  2768.0  3204.0
# 관악   264.0  322.0  10.0  12.0   7.0   6.0   937.0  2103.0  2707.0  3235.0
# 광진   234.0  279.0   6.0  11.0   4.0   4.0  1057.0  2636.0  2011.0  2392.0
# 구로   181.0  273.0  13.0  10.0   9.0   9.0   861.0  1910.0  2680.0  3164.0
# 금천   143.0  175.0   7.0   7.0   6.0   6.0   654.0  1264.0  1946.0  2193.0
# 남대문   52.0   57.0   4.0   5.0   1.0   1.0   429.0   946.0   832.0   890.0
# 노원   142.0  159.0   9.0   6.0   6.0   5.0   740.0  1857.0  2124.0  2516.0
# 도봉   121.0  123.0   5.0   5.0   3.0   3.0   492.0   866.0  1309.0  1441.0
# 동대문  158.0  190.0  12.0  10.0   5.0   5.0  1071.0  1940.0  2377.0  2642.0
# ...

# %%
crime_station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 강남 to 혜화
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   강간검거    31 non-null     float64
#  1   강간발생    31 non-null     float64
#  2   강도검거    31 non-null     float64
#  3   강도발생    31 non-null     float64
#  4   살인검거    31 non-null     float64
#  5   살인발생    31 non-null     float64
#  6   절도검거    31 non-null     float64
#  7   절도발생    31 non-null     float64
#  8   폭력검거    31 non-null     float64
#  9   폭력발생    31 non-null     float64
# dtypes: float64(10)
# memory usage: 3.7+ KB

# %%
dict_sample = {'Name': 'Zara', 'Age': 7, 'Class': 'First'}
dict_sample.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict_sample.values()
# Out:
# dict_values(['Zara', 7, 'First'])

# %%
dict_sample['Name']
# Out:
# 'Zara'

# %%
dict_sample.get('Age')
# Out:
# 7

# %%
real_gu = {'종로구' : ['종로', '혜화'], '중구' : ['남대문', '중부'],
          '용산구' : ['용산'], '성동구' : ['성동'],
          '광진구' : ['광진'], '동대문구' : ['동대문'],
          '중랑구' : ['중랑'], '성북구' : ['성북', '종암'],
          '강북구' : ['강북'], '도봉구' : ['도봉'],
          '노원구' : ['노원'], '은평구' : ['서부', '은평'],
          '서대문구' : ['서대문'], '마포구' : ['마포'],
          '양천구' : ['양천'], '강서구' : ['강서'],
          '구로구' : ['구로'], '금천구' : ['금천'],
          '영등포구' : ['영등포'], '동작구' : ['동작'],
          '관악구' : ['관악'], '서초구' : ['방배', '서초'],
          '강남구' : ['강남', '수서'], '송파구' : ['송파'],
          '강동구' : ['강동']}

# %%
for gu_name, station_name in real_gu.items():
    if '강남' in station_name:
        print(gu_name)
# Out:
# 강남구

# %%
tmp_gu = []

for station in crime_station.index:
    for gu_name, station_name in real_gu.items():
        if station in station_name:
            tmp_gu.append(gu_name)
            
tmp_gu
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '중구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서초구',
#  '서대문구',
#  '은평구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '강남구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '성북구',
#  '중랑구',
#  '중구',
#  '종로구']

# %%
crime_station['구'] = tmp_gu
crime_station
# Out:
#       강간검거   강간발생  강도검거  강도발생  살인검거  살인발생    절도검거    절도발생    폭력검거    폭력발생  \
# 구분
# 강남   269.0  339.0  26.0  24.0   3.0   3.0  1129.0  2438.0  2096.0  2336.0
# 강동   152.0  160.0  13.0  14.0   5.0   4.0   902.0  1754.0  2201.0  2530.0
# 강북   159.0  217.0   4.0   5.0   6.0   7.0   672.0  1222.0  2482.0  2778.0
# 강서   239.0  275.0  10.0  10.0  10.0   9.0  1070.0  1952.0  2768.0  3204.0
# 관악   264.0  322.0  10.0  12.0   7.0   6.0   937.0  2103.0  2707.0  3235.0
# 광진   234.0  279.0   6.0  11.0   4.0   4.0  1057.0  2636.0  2011.0  2392.0
# 구로   181.0  273.0  13.0  10.0   9.0   9.0   861.0  1910.0  2680.0  3164.0
# 금천   143.0  175.0   7.0   7.0   6.0   6.0   654.0  1264.0  1946.0  2193.0
# 남대문   52.0   57.0   4.0   5.0   1.0   1.0   429.0   946.0   832.0   890.0
# 노원   142.0  159.0   9.0   6.0   6.0   5.0   740.0  1857.0  2124.0  2516.0
# 도봉   121.0  123.0   5.0   5.0   3.0   3.0   492.0   866.0  1309.0  1441.0
# 동대문  158.0  190.0  12.0  10.0   5.0   5.0  1071.0  1940.0  2377.0  2642.0
# ...

# %%
crime_station.to_csv("./02. crime_in_Seoul.csv", sep=',', encoding='UTF-8')

# %%
crime_gu = pd.pivot_table(crime_station, index='구', aggfunc=np.sum)

crime_gu.head()
# Out:
#       강간검거   강간발생  강도검거  강도발생  살인검거  살인발생    절도검거    절도발생    폭력검거    폭력발생
# 구
# 강남구  413.0  516.0  42.0  39.0   5.0   5.0  1918.0  3587.0  3527.0  4002.0
# 강동구  152.0  160.0  13.0  14.0   5.0   4.0   902.0  1754.0  2201.0  2530.0
# 강북구  159.0  217.0   4.0   5.0   6.0   7.0   672.0  1222.0  2482.0  2778.0
# 강서구  239.0  275.0  10.0  10.0  10.0   9.0  1070.0  1952.0  2768.0  3204.0
# 관악구  264.0  322.0  10.0  12.0   7.0   6.0   937.0  2103.0  2707.0  3235.0

# %%
crime_gu['살인발생'].sort_values(ascending=False).head()
# Out:
# 구
# 영등포구    13.0
# 강서구      9.0
# 구로구      9.0
# 송파구      9.0
# 중랑구      8.0
# Name: 살인발생, dtype: float64

# %%
crime_gu['폭력발생'].sort_values(ascending=False).head()
# Out:
# 구
# 강남구     4002.0
# 영등포구    3593.0
# 송파구     3289.0
# 관악구     3235.0
# 강서구     3204.0
# Name: 폭력발생, dtype: float64

# %%
crime_gu['강도발생'].sort_values(ascending=False).head()
# Out:
# 구
# 강남구     39.0
# 영등포구    19.0
# 송파구     15.0
# 강동구     14.0
# 중랑구     14.0
# Name: 강도발생, dtype: float64

# %%
crime_gu['절도발생'].sort_values(ascending=False).head()
# Out:
# 구
# 강남구     3587.0
# 광진구     2636.0
# 송파구     2543.0
# 마포구     2527.0
# 영등포구    2341.0
# Name: 절도발생, dtype: float64

# %%
crime_gu['강간발생'].sort_values(ascending=False).head()
# Out:
# 구
# 강남구     516.0
# 서초구     428.0
# 마포구     399.0
# 영등포구    356.0
# 동작구     325.0
# Name: 강간발생, dtype: float64

# %%
crime_gu['강도검거']/crime_gu['강도발생']
# Out:
# 구
# 강남구     1.076923
# 강동구     0.928571
# 강북구     0.800000
# 강서구     1.000000
# 관악구     0.833333
# 광진구     0.545455
# 구로구     1.300000
# 금천구     1.000000
# 노원구     1.500000
# 도봉구     1.000000
# 동대문구    1.200000
# 동작구     1.000000
# 마포구     1.750000
# 서대문구    0.800000
# 서초구     0.769231
# 성동구     1.666667
# 성북구     1.000000
# 송파구     0.800000
# 양천구     1.000000
# 영등포구    0.736842
# 용산구     1.111111
# 은평구     0.777778
# 종로구     0.750000
# 중구      0.875000
# 중랑구     1.000000
# dtype: float64

# %%
num = ['강간검거', '강도검거', '살인검거', '절도검거', '폭력검거']
den = ['강간발생', '강도발생', '살인발생', '절도발생', '폭력발생']

crime_gu[num].div(crime_gu[den].values)
# Out:
#           강간검거      강도검거      살인검거      절도검거      폭력검거
# 구
# 강남구   0.800388  1.076923  1.000000  0.534709  0.881309
# 강동구   0.950000  0.928571  1.250000  0.514253  0.869960
# 강북구   0.732719  0.800000  0.857143  0.549918  0.893449
# 강서구   0.869091  1.000000  1.111111  0.548156  0.863920
# 관악구   0.819876  0.833333  1.166667  0.445554  0.836785
# 광진구   0.838710  0.545455  1.000000  0.400986  0.840719
# 구로구   0.663004  1.300000  1.000000  0.450785  0.847029
# 금천구   0.817143  1.000000  1.000000  0.517405  0.887369
# 노원구   0.893082  1.500000  1.200000  0.398492  0.844197
# 도봉구   0.983740  1.000000  1.000000  0.568129  0.908397
# 동대문구  0.831579  1.200000  1.000000  0.552062  0.899697
# 동작구   0.458462  1.000000  0.750000  0.451876  0.869356
# 마포구   0.802005  1.750000  1.000000  0.371983  0.850629
# 서대문구  0.840000  0.800000  1.166667  0.500333  0.831984
# 서초구   0.633178  0.769231  1.000000  0.502041  0.867836
# 성동구   0.750000  1.666667  1.250000  0.691358  0.869673
# ...

# %%
target = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']
num = ['강간검거', '강도검거', '살인검거', '절도검거', '폭력검거']
den = ['강간발생', '강도발생', '살인발생', '절도발생', '폭력발생']
crime_gu[target] = crime_gu[num].div(crime_gu[den].values)*100
crime_gu.head()
# Out:
#       강간검거   강간발생  강도검거  강도발생  살인검거  살인발생    절도검거    절도발생    폭력검거    폭력발생  \
# 구
# 강남구  413.0  516.0  42.0  39.0   5.0   5.0  1918.0  3587.0  3527.0  4002.0
# 강동구  152.0  160.0  13.0  14.0   5.0   4.0   902.0  1754.0  2201.0  2530.0
# 강북구  159.0  217.0   4.0   5.0   6.0   7.0   672.0  1222.0  2482.0  2778.0
# 강서구  239.0  275.0  10.0  10.0  10.0   9.0  1070.0  1952.0  2768.0  3204.0
# 관악구  264.0  322.0  10.0  12.0   7.0   6.0   937.0  2103.0  2707.0  3235.0
#
#          강간검거율       강도검거율       살인검거율      절도검거율      폭력검거율
# 구
# 강남구  80.038760  107.692308  100.000000  53.470867  88.130935
# 강동구  95.000000   92.857143  125.000000  51.425314  86.996047
# 강북구  73.271889   80.000000   85.714286  54.991817  89.344852
# 강서구  86.909091  100.000000  111.111111  54.815574  86.392010
# 관악구  81.987578   83.333333  116.666667  44.555397  83.678516

# %%
crime_gu = crime_gu.drop(columns=num)
crime_gu.head()
# Out:
#       강간발생  강도발생  살인발생    절도발생    폭력발생      강간검거율       강도검거율       살인검거율  \
# 구
# 강남구  516.0  39.0   5.0  3587.0  4002.0  80.038760  107.692308  100.000000
# 강동구  160.0  14.0   4.0  1754.0  2530.0  95.000000   92.857143  125.000000
# 강북구  217.0   5.0   7.0  1222.0  2778.0  73.271889   80.000000   85.714286
# 강서구  275.0  10.0   9.0  1952.0  3204.0  86.909091  100.000000  111.111111
# 관악구  322.0  12.0   6.0  2103.0  3235.0  81.987578   83.333333  116.666667
#
#          절도검거율      폭력검거율
# 구
# 강남구  53.470867  88.130935
# 강동구  51.425314  86.996047
# 강북구  54.991817  89.344852
# 강서구  54.815574  86.392010
# 관악구  44.555397  83.678516

# %%
crime_gu[target] > 100
# Out:
#       강간검거율  강도검거율  살인검거율  절도검거율  폭력검거율
# 구
# 강남구   False   True  False  False  False
# 강동구   False  False   True  False  False
# 강북구   False  False  False  False  False
# 강서구   False  False   True  False  False
# 관악구   False  False   True  False  False
# 광진구   False  False  False  False  False
# 구로구   False   True  False  False  False
# 금천구   False  False  False  False  False
# 노원구   False   True   True  False  False
# 도봉구   False  False  False  False  False
# 동대문구  False   True  False  False  False
# 동작구   False  False  False  False  False
# 마포구   False   True  False  False  False
# 서대문구  False  False   True  False  False
# 서초구   False  False  False  False  False
# 성동구   False   True   True  False  False
# 성북구   False  False  False  False  False
# 송파구   False  False  False  False  False
# 양천구   False  False  False  False  False
# 영등포구  False  False  False  False  False
# 용산구   False   True  False  False  False
# 은평구   False  False  False  False  False
# ...

# %%
crime_gu[crime_gu[target] > 100] =100
crime_gu
# Out:
#        강간발생  강도발생  살인발생    절도발생    폭력발생      강간검거율       강도검거율       살인검거율  \
# 구
# 강남구   516.0  39.0   5.0  3587.0  4002.0  80.038760  100.000000  100.000000
# 강동구   160.0  14.0   4.0  1754.0  2530.0  95.000000   92.857143  100.000000
# 강북구   217.0   5.0   7.0  1222.0  2778.0  73.271889   80.000000   85.714286
# 강서구   275.0  10.0   9.0  1952.0  3204.0  86.909091  100.000000  100.000000
# 관악구   322.0  12.0   6.0  2103.0  3235.0  81.987578   83.333333  100.000000
# 광진구   279.0  11.0   4.0  2636.0  2392.0  83.870968   54.545455  100.000000
# 구로구   273.0  10.0   9.0  1910.0  3164.0  66.300366  100.000000  100.000000
# 금천구   175.0   7.0   6.0  1264.0  2193.0  81.714286  100.000000  100.000000
# 노원구   159.0   6.0   5.0  1857.0  2516.0  89.308176  100.000000  100.000000
# 도봉구   123.0   5.0   3.0   866.0  1441.0  98.373984  100.000000  100.000000
# 동대문구  190.0  10.0   5.0  1940.0  2642.0  83.157895  100.000000  100.000000
# ...

# %%
crime_gu.rename(columns = {'강간발생':'강간',
                           '강도발생':'강도',
                           '살인발생':'살인',
                           '절도발생':'절도',
                           '폭력발생':'폭력'},
                inplace=True)

crime_gu.head()
# Out:
#         강간    강도   살인      절도      폭력      강간검거율       강도검거율       살인검거율  \
# 구
# 강남구  516.0  39.0  5.0  3587.0  4002.0  80.038760  100.000000  100.000000
# 강동구  160.0  14.0  4.0  1754.0  2530.0  95.000000   92.857143  100.000000
# 강북구  217.0   5.0  7.0  1222.0  2778.0  73.271889   80.000000   85.714286
# 강서구  275.0  10.0  9.0  1952.0  3204.0  86.909091  100.000000  100.000000
# 관악구  322.0  12.0  6.0  2103.0  3235.0  81.987578   83.333333  100.000000
#
#          절도검거율      폭력검거율
# 구
# 강남구  53.470867  88.130935
# 강동구  51.425314  86.996047
# 강북구  54.991817  89.344852
# 강서구  54.815574  86.392010
# 관악구  44.555397  83.678516

# %%
col = ['살인', '강도', '강간', '절도', '폭력']
crime_gu_norm = crime_gu[col] / crime_gu[col].max()
crime_gu_norm.head()
# Out:
#            살인        강도        강간        절도        폭력
# 구
# 강남구  0.384615  1.000000  1.000000  1.000000  1.000000
# 강동구  0.307692  0.358974  0.310078  0.488988  0.632184
# 강북구  0.538462  0.128205  0.420543  0.340675  0.694153
# 강서구  0.692308  0.256410  0.532946  0.544187  0.800600
# 관악구  0.461538  0.307692  0.624031  0.586284  0.808346

# %%
col2 = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']
crime_gu_norm[col2] = crime_gu[col2]
crime_gu_norm.head()
# Out:
#            살인        강도        강간        절도        폭력      강간검거율       강도검거율  \
# 구
# 강남구  0.384615  1.000000  1.000000  1.000000  1.000000  80.038760  100.000000
# 강동구  0.307692  0.358974  0.310078  0.488988  0.632184  95.000000   92.857143
# 강북구  0.538462  0.128205  0.420543  0.340675  0.694153  73.271889   80.000000
# 강서구  0.692308  0.256410  0.532946  0.544187  0.800600  86.909091  100.000000
# 관악구  0.461538  0.307692  0.624031  0.586284  0.808346  81.987578   83.333333
#
#           살인검거율      절도검거율      폭력검거율
# 구
# 강남구  100.000000  53.470867  88.130935
# 강동구  100.000000  51.425314  86.996047
# 강북구   85.714286  54.991817  89.344852
# 강서구  100.000000  54.815574  86.392010
# 관악구  100.000000  44.555397  83.678516

# %%
col = ['강간', '강도', '살인', '절도', '폭력']
crime_gu_norm['범죄'] = np.mean(crime_gu_norm[col], axis=1)
crime_gu_norm.head()
# Out:
#            살인        강도        강간        절도        폭력      강간검거율       강도검거율  \
# 구
# 강남구  0.384615  1.000000  1.000000  1.000000  1.000000  80.038760  100.000000
# 강동구  0.307692  0.358974  0.310078  0.488988  0.632184  95.000000   92.857143
# 강북구  0.538462  0.128205  0.420543  0.340675  0.694153  73.271889   80.000000
# 강서구  0.692308  0.256410  0.532946  0.544187  0.800600  86.909091  100.000000
# 관악구  0.461538  0.307692  0.624031  0.586284  0.808346  81.987578   83.333333
#
#           살인검거율      절도검거율      폭력검거율        범죄
# 구
# 강남구  100.000000  53.470867  88.130935  0.876923
# 강동구  100.000000  51.425314  86.996047  0.419583
# 강북구   85.714286  54.991817  89.344852  0.424407
# 강서구  100.000000  54.815574  86.392010  0.565290
# 관악구  100.000000  44.555397  83.678516  0.557578

# %%
col = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율']
crime_gu_norm['검거'] = np.mean(crime_gu_norm[col], axis=1)
crime_gu_norm.head()
# Out:
#            살인        강도        강간        절도        폭력      강간검거율       강도검거율  \
# 구
# 강남구  0.384615  1.000000  1.000000  1.000000  1.000000  80.038760  100.000000
# 강동구  0.307692  0.358974  0.310078  0.488988  0.632184  95.000000   92.857143
# 강북구  0.538462  0.128205  0.420543  0.340675  0.694153  73.271889   80.000000
# 강서구  0.692308  0.256410  0.532946  0.544187  0.800600  86.909091  100.000000
# 관악구  0.461538  0.307692  0.624031  0.586284  0.808346  81.987578   83.333333
#
#           살인검거율      절도검거율      폭력검거율        범죄         검거
# 구
# 강남구  100.000000  53.470867  88.130935  0.876923  84.328112
# 강동구  100.000000  51.425314  86.996047  0.419583  85.255701
# 강북구   85.714286  54.991817  89.344852  0.424407  76.664569
# 강서구  100.000000  54.815574  86.392010  0.565290  85.623335
# 관악구  100.000000  44.555397  83.678516  0.557578  78.710965

# %%
crime_gu_norm['범죄'].sort_values(ascending=False).head()
# Out:
# 구
# 강남구     0.876923
# 영등포구    0.745508
# 송파구     0.612240
# 강서구     0.565290
# 구로구     0.560174
# Name: 범죄, dtype: float64

# %%
crime_gu_norm['검거'].sort_values(ascending=False).head()
# Out:
# 구
# 도봉구     89.205322
# 성동구     86.220613
# 동대문구    85.666760
# 강서구     85.623335
# 중랑구     85.377882
# Name: 검거, dtype: float64

# %%
crime_gu_norm['검거'].sort_values().head()
# Out:
# 구
# 종로구     61.930524
# 동작구     70.593867
# 영등포구    72.146149
# 광진구     72.517393
# 송파구     74.821606
# Name: 검거, dtype: float64

# %%
import seaborn as sns

target_col = ['강간검거율', '강도검거율', '살인검거율', '절도검거율', '폭력검거율', '검거']

crime_gu_norm_sort = crime_gu_norm.sort_values(by='검거', ascending=False)

plt.figure(figsize=(10,10))
sns.heatmap(crime_gu_norm_sort[target_col],
            annot=True, fmt='f', linewidths=.5, cmap='RdPu')
plt.title('범죄 검거 비율 (정규화된 검거의 합으로 정렬)')
plt.autoscale()
plt.tight_layout(pad=5)
plt.show()

# %%
target_col = target_col = ['강간', '강도', '살인', '절도', '폭력', '범죄']

crime_gu_norm_sort = crime_gu_norm.sort_values(by='범죄', ascending=False)

plt.figure(figsize=(10,10))
sns.heatmap(crime_gu_norm_sort[target_col],
            annot=True, fmt='f', linewidths=.5, cmap='RdPu')
plt.title('범죄 비율 (정규화된 검거의 합으로 정렬)')
plt.autoscale()
plt.show()

# %%
crime_gu.to_csv("./02. crime_in_Seoul.csv", sep=',', encoding='UTF-8')

# %%
# %pwd
# Out:
# 'C:\\Users\\ASUS\\Documents'
